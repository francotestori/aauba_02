# %%
import librosa
from IPython.display import Audio
import matplotlib.pyplot as plt
import numpy as np
import soundfile as sf
from pathlib import Path

# Import de Librerías
import librosa
import glob
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from IPython.display import Audio
from librosa.display import specshow

import os
import math
import ntpath

# %%
import librosa
limpio, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3.wav')
blanco3000, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3_BLANCO3000.wav')
blanco1000, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3_BLANCO1000.wav')
blanco300, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3_BLANCO300.wav')
blanco100, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3_BLANCO100.wav')
blanco30, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3_BLANCO30.wav')
blanco10, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3_BLANCO10.wav')
blanco3, sr = librosa.load('audios_ejemplo/1b4c9b89_nohash_3_BLANCO3.wav')

# %%
Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(blanco3000, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(blanco1000, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(blanco300, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(blanco100, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(blanco30, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(blanco10, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(blanco3, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
